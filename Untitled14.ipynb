# %% [markdown]
# <a href="https://colab.research.google.com/github/patriciamediavilla/L1P2/blob/main/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Práctica final Visualización de datos
#
# ## Volumen de ventas de bebidas
#
# ### Patricia Mediavilla

# %% [markdown]
# En esta práctica se van a realizar unas gráficas con el fin de visualizar contenido necesario para poder entender mejor la base de datos.
#
# Para ello vamos a cargar la base de datos y así poder hacer primero un estudio un poco más detallado de la base de datos y de las variables que se utilizan para que la ejecución de la práctica sea más directa.

# %% [markdown]
# ## Cargar librerías

# %% [markdown]
# Para relizar las gráficas debemos cargar las librerías necesarias

# %%
pip install plotly_express
# Out:
# Collecting plotly_express
#   Downloading plotly_express-0.4.1-py2.py3-none-any.whl (2.9 kB)
# Requirement already satisfied: pandas>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from plotly_express) (1.5.3)
# Requirement already satisfied: plotly>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from plotly_express) (5.15.0)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from plotly_express) (0.14.1)
# Requirement already satisfied: scipy>=0.18 in /usr/local/lib/python3.10/dist-packages (from plotly_express) (1.11.4)
# Requirement already satisfied: patsy>=0.5 in /usr/local/lib/python3.10/dist-packages (from plotly_express) (0.5.6)
# Requirement already satisfied: numpy>=1.11 in /usr/local/lib/python3.10/dist-packages (from plotly_express) (1.23.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.20.0->plotly_express) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.20.0->plotly_express) (2023.3.post1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5->plotly_express) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=4.1.0->plotly_express) (8.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly>=4.1.0->plotly_express) (23.2)
# Installing collected packages: plotly_express
# Successfully installed plotly_express-0.4.1

# %%
import plotly_express as px
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Lectura y limpieza de los datos
#
# Lo primero que debemos hacer es importar la base de datos para poder comprenderla y ver la limpieza y los cambios que necesita.
#
# En este caso tenemos una base de datos que nos proporciona los volúmenes de venta de bebidas.

# %%
df = pd.read_csv('Datos_practica_final_python.csv', sep=',')
df
# Out:
#               MU           BU SECTOR   COUNTRY            SUBBRAND  YEAR  \
# 0         GC Bev       GC Bev   APAC     China            7up (L3)  2023
# 1      India Bev        India  AMESA     India  Pepsi Regular (L3)  2023
# 2      India Bev        India  AMESA     India  Pepsi Regular (L3)  2022
# 3         GC Bev       GC Bev   APAC     China            7up (L3)  2024
# 4         Mexico   LAB Mexico  LATAM    Mexico       7up Free (L3)  2023
# ...          ...          ...    ...       ...                 ...   ...
# 40667     GC Bev       GC Bev   APAC     China      Other Csd (L3)  2022
# 40668     GC Bev       GC Bev   APAC     China      Other Csd (L3)  2021
# 40669     GC Bev       GC Bev   APAC     China   Mountain Dew (L3)  2022
# 40670   Colombia  LAB Central  LATAM  Colombia       Gatorade (L3)  2023
# 40671      Chile  LAB Central  LATAM     Chile         Lipton (L3)  2018
#
#        PERIOD     SCENARIO        AMOUNT  MONTH  FORECAST_YEAR FORECAST  UNIT
# 0           4  AI_forecast  1.957937e+06      3         2022.0  AI_P07F  8 OZ
# 1           9  AI_forecast  9.390326e+06      8         2022.0  AI_P07F  8 OZ
# 2           9  AI_forecast  6.865113e+06      8         2022.0  AI_P08F  8 OZ
# 3           3  AI_forecast  2.133347e+06      2         2022.0  AI_P12F  8 OZ
# 4           6  AI_forecast  3.493313e+06      5         2022.0  AI_P12F  8 OZ
# ...       ...          ...           ...    ...            ...      ...   ...
# 40667      12       actual  3.701179e+04     11            NaN      NaN  8 OZ
# 40668       2       actual  1.904533e+04      1            NaN      NaN  8 OZ
# 40669      13       actual  3.796398e+02     12            NaN      NaN  8 OZ
# 40670       8       actual  1.730219e+06      7            NaN      NaN  8 OZ
# 40671       8       actual  6.594905e+04      7            NaN      NaN  8 OZ
#
# [40672 rows x 13 columns]

# %% [markdown]
# Como hemos explicado se refieren a las ventas de bebidas de una compañia en concreto en diferentes paises.
#
# Las variables que se utilizan son:
# - COUNTRY: País al que corresponde el registro.
# - MU (Market unit): Grupos de paises (los grupos se llaman market units). La MU tiene
# menos granularidad por tanto que el país (dentro de una MU hay varios países).
# - BU (Business unit): Grupos de MUs (los grupos se llaman Business units). La BU tiene
# menos granularidad por tanto que la MU (dentro de una BU hay varias MU).
# - SECTOR: Grupos de Bus. Es el nivel de menos granularidad posible.
# - SUBBRAND: Dentro de cada país, encontramos varios “productos” (o marcas).
# - YEAR: Año al que pertenece el registro
# - PERIOD: Periodo al que pertenece el registro. Es exactamente lo mismo que los meses, pero va de 2 a 13 en lugar de 1 a 12 (el dos pertenece a enero, el 3 a febrero...)
# - SCENARIO: Nos indica el tipo de dato que es el registro
# - AMOUNT: Valor del registro
# - MONTH: Mes al que pertenece el registro (de 1 a 12)
# - FORECAST_YEAR: En caso de tratarse el registro de una predicción, año en el que se hizo la predicción
# - FORECAST: En caso de tratarse el registro de una predicción, periodo en el que se hizo la predicción
# - UNIT: Unidad de volumen en la que esta el registro (siempre 8OZ)

# %% [markdown]
# ## Pregunta 1
#
# Clasifica cada uno de los campos en uno de los siguientes cuatro grupos:
# - Campos que indican información de la granularidad:
#   - **COUNTRY**
#   - **MU (Market unit)**
#   - **BU (Business unit)**
#   - **SECTOR**
#   - **SUBBRAND**
# - Campos que indican información temporal:
#   - **YEAR**
#   - **PERIOD**
#   - **MONTH**
#   - **FORECAST_YEAR**
#   - **FORECAST**
# - Campos que indican información acerca del propio valor del registro:
#   - **AMOUNT**
#   - **UNIT**
# - Campo que nos indique si el registro es un valor real o una predicción:
#   - **SCENARIO**
#
# Ordena la tabla para que los
# campos de cada grupo estén juntos.

# %%
df = df[['COUNTRY', 'MU', 'BU', 'SECTOR', 'SUBBRAND', 'YEAR', 'PERIOD', 'MONTH', 'FORECAST_YEAR', 'FORECAST', 'AMOUNT', 'UNIT', 'SCENARIO']]
df
# Out:
#                   COUNTRY           MU              BU SECTOR        SUBBRAND  \
# 28307           Australia      ANZ Bev             ANZ   APAC        7up (L3)
# 2511            Australia      ANZ Bev             ANZ   APAC        7up (L3)
# 3726            Australia      ANZ Bev             ANZ   APAC        7up (L3)
# 461             Australia      ANZ Bev             ANZ   APAC        7up (L3)
# 25083           Australia      ANZ Bev             ANZ   APAC        7up (L3)
# ...                   ...          ...             ...    ...             ...
# 12420  UnitedArabEmirates  Gulf Bev CU  UAE & Gulf F&B  AMESA  Tropicana (L3)
# 11281  UnitedArabEmirates  Gulf Bev CU  UAE & Gulf F&B  AMESA  Tropicana (L3)
# 5314   UnitedArabEmirates  Gulf Bev CU  UAE & Gulf F&B  AMESA  Tropicana (L3)
# 30080  UnitedArabEmirates  Gulf Bev CU  UAE & Gulf F&B  AMESA  Tropicana (L3)
# 31215  UnitedArabEmirates  Gulf Bev CU  UAE & Gulf F&B  AMESA  Tropicana (L3)
#
#        YEAR  PERIOD  MONTH  FORECAST_YEAR FORECAST         AMOUNT  UNIT  \
# 28307  2018       2      1            NaN      NaN  130765.323734  8 OZ
# 2511   2018       3      2            NaN      NaN  104432.452995  8 OZ
# 3726   2018       4      3            NaN      NaN  133417.024964  8 OZ
# 461    2018       5      4            NaN      NaN  127945.129726  8 OZ
# 25083  2018       6      5            NaN      NaN  133308.242869  8 OZ
# ...     ...     ...    ...            ...      ...            ...   ...
# 12420  2024       4      3         2022.0  AI_P11F       0.000000  8 OZ
# 11281  2024       4      3         2022.0  AI_P12F       0.000000  8 OZ
# 5314   2024       5      4         2022.0  AI_P11F       0.000000  8 OZ
# 30080  2024       5      4         2022.0  AI_P12F       0.000000  8 OZ
# 31215  2024       6      5         2022.0  AI_P12F       0.000000  8 OZ
#
#           SCENARIO
# 28307       actual
# 2511        actual
# 3726        actual
# 461         actual
# 25083       actual
# ...            ...
# 12420  AI_forecast
# 11281  AI_forecast
# 5314   AI_forecast
# 30080  AI_forecast
# 31215  AI_forecast
#
# [40672 rows x 13 columns]

# %% [markdown]
# Una vez entendidas las variables y ordenadas de manera que sea más facil la realización de la práctica, vamos a hacer un pequeño procesamiento de los datos para ver si hayq ue hacer alguna modificación o está todo perfecto.
#
# Lo primero que haremos es ver si hay valores faltantes.

# %%
df.isnull().sum()
# Out:
# COUNTRY             0
# MU                  0
# BU                  0
# SECTOR              0
# SUBBRAND          216
# YEAR                0
# PERIOD              0
# MONTH               0
# FORECAST_YEAR    8968
# FORECAST         8968
# AMOUNT              0
# UNIT                0
# SCENARIO            0
# dtype: int64

# %% [markdown]
# Hay algunos valores faltantes pero no nos importan porque por ejemplo refiriendonos a als varibles FORECAST y FORECAST_YEAR, solo están relleno si el valor de SCENARIO es forecast, por lo que estaría bien y en la variable SUBBRAND puede ser aque algunas bebidas no tengan el último grado de granularidad por lo que también se considera correcto.
#
# Ahora estudiaremos si las varibles numéricas están bien o hay algún outlier, como por ejemplo, la variable AMOUNT  si es negativo habría que modificarlo, ya que no podría ser por que el volumen de ventas siempre tiene que ser mayor o igual que 0.

# %%
df.describe()
# Out:
#                YEAR        PERIOD         MONTH  FORECAST_YEAR        AMOUNT
# count  40672.000000  40672.000000  40672.000000        31704.0  4.067200e+04
# mean    2022.219070      7.491345      6.491345         2022.0  2.465570e+06
# std        1.319282      3.443474      3.443474            0.0  8.792445e+06
# min     2018.000000      2.000000      1.000000         2022.0  0.000000e+00
# 25%     2022.000000      5.000000      4.000000         2022.0  1.288016e+04
# 50%     2023.000000      7.000000      6.000000         2022.0  1.544796e+05
# 75%     2023.000000     10.000000      9.000000         2022.0  1.493294e+06
# max     2024.000000     13.000000     12.000000         2022.0  2.271331e+08

# %% [markdown]
# Vemos que todos los datos son reales y no hay outliers asi que concluimos que las varibles numéricas son correctas, estudiemos ahora las categóricas.

# %%
# Lista de columnas
columnas = ['COUNTRY','MU','BU','SECTOR', 'SUBBRAND', 'FORECAST', 'UNIT', 'SCENARIO']

# Itera a través de las columnas y muestra el conteo de valores únicos
for columna in columnas:
    conteo_valores = df[columna].value_counts()
    print(f'Conteo de valores en la columna "{columna}":')
    print(conteo_valores)
    print('\n')
# Out:
# Conteo de valores en la columna "COUNTRY":
# Great Britain         4548
# India                 4526
# Mexico                4182
# UnitedArabEmirates    4087
# China                 3928
# Spain                 3617
# Pakistan              3322
# Chile                 3158
# South Korea           2754
# Australia             2597
# Colombia              2243
# Sweden                1710
# Name: COUNTRY, dtype: int64
#
#
# Conteo de valores en la columna "MU":
# GBI FOBO        4548
# India Bev       4526
# Mexico          4182
# Gulf Bev CU     4087
# GC Bev          3928
# Spain           3617
# Pakistan Bev    3322
# Chile           3158
# North Asia      2754
# ANZ Bev         2597
# Colombia        2243
# NE FOBO         1710
# Name: MU, dtype: int64
#
#
# Conteo de valores en la columna "BU":
# FOBO BU                 6258
# LAB Central             5401
# India                   4526
# LAB Mexico              4182
# UAE & Gulf F&B          4087
# GC Bev                  3928
# SWE                     3617
# Pakistan                3322
# Asia Beverages & GMD    2754
# ANZ                     2597
# Name: BU, dtype: int64
#
#
# Conteo de valores en la columna "SECTOR":
# AMESA     11935
# Europe     9875
# LATAM      9583
# APAC       9279
# Name: SECTOR, dtype: int64
#
#
# Conteo de valores en la columna "SUBBRAND":
# Pepsi Regular (L3)           3468
# 7up (L3)                     3433
# Gatorade (L3)                3429
# Pepsi Max (L3)               3392
# Diet Pepsi (L3)              3133
# Mountain Dew (L3)            2788
# Lipton (L3)                  2620
# 7up Free (L3)                2464
# Mirinda (L3)                 2206
# Tropicana (L3)               1322
# Aquafina (L3)                1148
# Other Csd (L3)               1111
# All Other Csd (L3)            861
# Rockstar (L3)                 756
# Life Water (L3)               735
# Slice (L3)                    574
# Kas (L3)                      574
# Sobe (L3)                     288
# Manzanita Sol (L3)            287
# 7up Nimbooz (L3)              287
# Be Light (L3)                 287
# Dukes (L3)                    287
# Aquarade By Radical (L3)      287
# Bitter Kas (L3)               287
# Nimbooz (L3)                  287
# V Water (L3)                  263
# Kas Fruit (L3)                262
# Starbucks (L3)                259
# Bubly (L3)                    255
# Radical Fruit (L3)            253
# Rockstar Juiced (L3)          252
# Rockstar Xdurance (L3)        252
# Rockstar Baja (L3)            252
# Rockstar Punched (L3)         251
# Rockstar Super Sours (L3)     249
# Dole Juice (L3)               249
# Rockstar Xd Power (L3)        247
# Quaker (L3)                   242
# Ceres (L3)                    239
# Slice Fizzy (L3)              238
# Ocean Spray (L3)              216
# Gatorade No Sugar (L3)        102
# Diet 7up (L3)                  64
# Name: SUBBRAND, dtype: int64
#
#
# Conteo de valores en la columna "FORECAST":
# AI_PF      2628
# AI_P02F    2628
# AI_P03F    2628
# AI_P04F    2628
# AI_P05F    2628
# AI_P06F    2628
# AI_P07F    2628
# AI_P08F    2628
# AI_P09F    2628
# AI_P10F    2628
# AI_P11F    2628
# AI_P12F    2628
# AI_AOP      168
# Name: FORECAST, dtype: int64
#
#
# Conteo de valores en la columna "UNIT":
# 8 OZ    40672
# Name: UNIT, dtype: int64
#
#
# Conteo de valores en la columna "SCENARIO":
# AI_forecast    31704
# actual          8968
# Name: SCENARIO, dtype: int64

# %% [markdown]
# Tras entender bien los valores vemos que no hay ningún outlier ni valores extraños.
#
# Por lo que una vez procesados los datos podemos empezar con el trabajo y responder a las preguntas.

# %% [markdown]
# ## Pregunta 2
#
# Con relación a los valores reales (no predicciones), ¿Cuál es el volumen total de cada
# uno de los sectores, cual es el sector con más volumen y cuál es el país con más volumen dentro del sector con más volumen?

# %%
import pandas as pd
import plotly.express as px

# Supongamos que tu DataFrame se llama df

# Filtra los registros que corresponden a valores reales (no predicciones)
real_data = df[df['SCENARIO'] == 'actual']

# Agrupa por sector y suma los volúmenes
sector_volumes = real_data.groupby('SECTOR')['AMOUNT'].sum().reset_index()

# Encuentra el sector con el volumen máximo
max_sector = sector_volumes.loc[sector_volumes['AMOUNT'].idxmax(), 'SECTOR']

# Filtra los registros del sector con más volumen
max_sector_data = real_data[real_data['SECTOR'] == max_sector]

# Agrupa por país y suma los volúmenes dentro del sector con más volumen
country_volumes = max_sector_data.groupby('COUNTRY')['AMOUNT'].sum()

# Encuentra el país con el volumen máximo dentro del sector con más volumen
max_country_in_max_sector = country_volumes.idxmax()

# Configura el índice del DataFrame sector_volumes a la columna 'SECTOR'
sector_volumes = sector_volumes.set_index('SECTOR')

# Ordena el DataFrame sector_volumes de mayor a menor
sector_volumes = sector_volumes.sort_values(by='AMOUNT', ascending=False)

# Gráfico de barras interactivo con Plotly Express para el volumen total de cada sector
fig_sector = px.bar(sector_volumes, x='AMOUNT', y=sector_volumes.index,
                    text='AMOUNT', title='Volumen Total por Sector',
                    labels={'AMOUNT': 'Volumen'}, color='AMOUNT',
                    color_continuous_scale='blues')

# Ordena country_volumes de mayor a menor
country_volumes = country_volumes.sort_values(ascending=False)

# Gráfico interactivo con Plotly Express para el volumen por país dentro del sector con más volumen
fig_country = px.bar(country_volumes, x=country_volumes.values, y=country_volumes.index,
                     title=f'Volumen por País en el Sector {max_sector}',
                     labels={'AMOUNT': 'Volumen'}, color=country_volumes.values,
                     color_continuous_scale='blues')

# Mostrar las figuras interactivas
fig_sector.show()
fig_country.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="1300ccba-4746-4b11-9249-bc2f9001a521" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1300ccba-4746-4b11-9249-bc2f9001a521")) {                    Plotly.newPlot(                        "1300ccba-4746-4b11-9249-bc2f9001a521",                        [{"alignmentgroup":"True","hovertemplate":"Volumen=%{marker.color}\u003cbr\u003eSECTOR=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[6547002275.745339,6358591125.683245,4941591001.952687,1406771783.7985709],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"text":[6547002275.745339,6358591125.683245,4941591001.952687,1406771783.7985709],"textposition":"auto","x":[6547002275.745339,6358591125.683245,4941591001.952687,1406771783.7985709],"xaxis":"x","y":["APAC","AMESA","LATAM","Europe"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="aa22bd62-9573-457d-b7a9-e5fd6c53fab7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aa22bd62-9573-457d-b7a9-e5fd6c53fab7")) {                    Plotly.newPlot(                        "aa22bd62-9573-457d-b7a9-e5fd6c53fab7",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}\u003cbr\u003eCOUNTRY=%{y}\u003cbr\u003ecolor=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[5567806321.739904,534753018.35478115,444442935.6506545],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[5567806321.739904,534753018.35478115,444442935.6506545],"xaxis":"x","y":["China","South Korea","Australia"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fi ...

# %% [markdown]
# ## Pregunta 3
#
# ¿Cuáles son las predicciones hechas para el país con más volumen del sector con más
# volumen (el país de la pregunta anterior) en los periodos 2 y 3 del año 2022? Atención:
# Hechas en los periodos 2 y 3 significa que se hicieron en ese momento del tiempo,
# pero al tener un horizonte de previsión de 18 periodos se habrán hecho para varios
# periodos futuros en ese momento. A simple vista, ¿Cuál de las previsiones te parece
# mejor, sabiendo ahora los datos reales que hubo posteriormente?

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Supongamos que tu DataFrame se llama df

# Filtra los registros correspondientes a predicciones para el país y sector en cuestión
predictions = df[(df['SCENARIO'] == 'AI_forecast') & (df['COUNTRY'] == max_country_in_max_sector) & (df['SECTOR'] == max_sector)]

# Filtra las predicciones para los periodos 2 y 3 del año 2022
predictions_2022_2 = predictions[(predictions['YEAR'] == 2022) & (predictions['FORECAST'] == 'AI_P02F')]
predictions_2022_3 = predictions[(predictions['YEAR'] == 2022) & (predictions['FORECAST'] == 'AI_P03F')]

# Ordena las predicciones por año y periodo para asegurar el orden temporal
predictions_2022_2 = predictions_2022_2.sort_values(by=['YEAR', 'PERIOD'])
predictions_2022_3 = predictions_2022_3.sort_values(by=['YEAR', 'PERIOD'])

#Creamos una varible fecha
df['Fecha'] = pd.to_datetime(df[['YEAR', 'MONTH']].assign(DAY=1))

# Filtra los datos reales correspondientes
actual_data = df[(df['SCENARIO'] == 'actual') & (df['COUNTRY'] == max_country_in_max_sector)]

# Ordena los datos reales por año y periodo
actual_data = actual_data.sort_values(by=['YEAR', 'PERIOD'])

sum_actual_data = actual_data.groupby('PERIOD')['AMOUNT'].sum().reset_index()
sum_forecast_data_2 = predictions_2022_2.groupby('PERIOD')['AMOUNT'].sum().reset_index()
sum_forecast_data_3 = predictions_2022_3.groupby('PERIOD')['AMOUNT'].sum().reset_index()

# Crear un gráfico de series temporales para comparar predicciones y datos reales
plt.figure(figsize=(10, 6))

# Plotear la serie temporal actual
plt.plot(mean_actual_data['PERIOD'], mean_actual_data['AMOUNT'], label="Actual", linestyle='-', marker='.', linewidth=1, alpha=1)

# Plotear la serie temporal de predicciones
plt.plot(mean_forecast_data['PERIOD'], mean_forecast_data['AMOUNT'], label="Predicciones", linestyle='-', marker='.', linewidth=1, alpha=1)

# Configuraciones adicionales del gráfico
plt.title(f"Comparación de Series Temporales - País: {max_country_in_max_sector} - Sector: {max_sector}")
plt.xlabel('Periodo')
plt.ylabel('Volumen')
plt.legend()
plt.grid(True)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ## Pregunta 4
#
# Calcula el error absoluto total de cada una de las dos predicciones (la que se hizo en el
# periodo 2 y la que se hizo en el periodo 3). Ejemplo: la predicción hecha en el periodo
# 2 tuvo un error para el periodo 3 de 50, un error para el periodo 4 de 60... una vez
# tengo todos, los sumo. Lo mismo para la predicción hecha en el periodo 3. ¿Cuál de las
# dos predicciones fue mejor en base a esos dos errores totales? De la mejor predicción,
# ¿Cuál fue el error cometido en cada periodo (lo que ya has calculado, antes de sumar,
# enséñamelo en una gráfica)?

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Supongamos que tu DataFrame se llama df

# Filtra los registros correspondientes a predicciones para el país y sector en cuestión
predictions = df[(df['SCENARIO'] == 'AI_forecast') & (df['COUNTRY'] == max_country_in_max_sector) & (df['SECTOR'] == max_sector)]

# Filtra las predicciones para los periodos 2 y 3 del año 2022
predictions_2022 = predictions[(predictions['YEAR'] == 2022) & (predictions['PERIOD'].isin([2, 3]))]

# Ordena las predicciones por año y periodo para asegurar el orden temporal
predictions_2022 = predictions_2022.sort_values(by=['YEAR', 'PERIOD'])

# Filtra los datos reales correspondientes
actual_data = df[(df['SCENARIO'] == 'actual') & (df['COUNTRY'] == max_country_in_max_sector) & (df['SECTOR'] == max_sector)]

# Ordena los datos reales por año y periodo
actual_data = actual_data.sort_values(by=['YEAR', 'PERIOD'])

# Calcula el error absoluto total para la predicción del periodo 2
error_total_period_2 = abs(predictions_2022[predictions_2022['FORECAST'] == 2]['AMOUNT'] - actual_data[actual_data['PERIOD'] == 3]['AMOUNT']).sum()

# Calcula el error absoluto total para la predicción del periodo 3
error_total_period_3 = abs(predictions_2022[predictions_2022['FORECAST'] == 3]['AMOUNT'] - actual_data[actual_data['PERIOD'] == 3]['AMOUNT']).sum()

# Muestra los errores totales
print(f"Error total para la predicción del periodo 2: {error_total_period_2}")
print(f"Error total para la predicción del periodo 3: {error_total_period_3}")

# Visualiza el error cometido en cada periodo en una gráfica
plt.figure(figsize=(10, 6))

# Grafica el error cometido en cada periodo para la predicción del periodo 2
plt.plot(actual_data[actual_data['PERIOD'] == 3]['PERIOD'], abs(predictions_2022[predictions_2022['FORECAST'] == 2]['AMOUNT'] - actual_data[actual_data['PERIOD'] == 3]['AMOUNT']), label="Predicción Periodo 2")

# Grafica el error cometido en cada periodo para la predicción del periodo 3
plt.plot(actual_data[actual_data['PERIOD'] == 3]['PERIOD'], abs(predictions_2022[predictions_2022['FORECAST'] == 3]['AMOUNT'] - actual_data[actual_data['PERIOD'] == 3]['AMOUNT']), label="Predicción Periodo 3")

# Configuraciones adicionales del gráfico
plt.title(f"Errores Cometidos en Cada Periodo - País: {max_country_in_max_sector} - Sector: {max_sector}")
plt.xlabel('Periodo')
plt.ylabel('Error Absoluto')
plt.legend()
plt.grid(True)

# Mostrar el gráfico
plt.show()
# Out:
# Error total para la predicción del periodo 2: 0.0
# Error total para la predicción del periodo 3: 0.0

# %%
# Calcula el error absoluto para cada periodo
error_2 = abs(predictions_2022[predictions_2022['FORECAST'] == 2]['AMOUNT'].values - actual_data[actual_data['PERIOD'] == 3]['AMOUNT'].values).sum()
error_3 = abs(predictions_2022[predictions_2022['FORECAST'] == 3]['AMOUNT'].values - actual_data[actual_data['PERIOD'] == 3]['AMOUNT'].values).sum()

# Compara los errores totales
if error_2 < error_3:
    mejor_prediccion = 2
else:
    mejor_prediccion = 3

# Muestra los errores cometidos en cada periodo en una gráfica
plt.figure(figsize=(10, 6))

# Plotear los errores cometidos en cada periodo
plt.plot(predictions_2022[predictions_2022['FORECAST'] == mejor_prediccion]['PERIOD'],
         abs(predictions_2022[predictions_2022['FORECAST'] == mejor_prediccion]['AMOUNT'].values - actual_data[actual_data['PERIOD'] == 3]['AMOUNT'].values),
         label=f'Error Absoluto - Predicción {mejor_prediccion}')

# Configuraciones adicionales del gráfico
plt.title(f"Errores Absolutos de las Predicciones - País: {max_country_in_max_sector} - Sector: {max_sector}")
plt.xlabel('Periodo')
plt.ylabel('Error Absoluto')
plt.legend()
plt.grid(True)

# Mostrar el gráfico
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-88-2ff6739d2834> in <cell line: 2>()
#       1 # Calcula el error absoluto para cada periodo
# ----> 2 error_2 = abs(predictions_2022[predictions_2022['FORECAST'] == 2]['AMOUNT'].values - actual_data[actual_data['PERIOD'] == 3]['AMOUNT'].values).sum()
#       3 error_3 = abs(predictions_2022[predictions_2022['FORECAST'] == 3]['AMOUNT'].values - actual_data[actual_data['PERIOD'] == 3]['AMOUNT'].values).sum()
#       4
#       5 # Compara los errores totales
#
# ValueError: operands could not be broadcast together with shapes (0,) (73,)
