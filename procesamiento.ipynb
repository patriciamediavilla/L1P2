# %% [markdown]
# <a href="https://colab.research.google.com/github/patriciamediavilla/L1P2/blob/main/procesamiento.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Procesamiento multimedia

# %%
# !pip install opencv-python
# !pip install opencv_jupyter_ui
# !pip install -q ipycanvas==0.11
from google.colab import output
output.enable_custom_widget_manager()
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 255.7/255.7 kB 3.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 7.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 255.8/255.8 kB 2.8 MB/s eta 0:00:00

# %%
import cv2
import opencv_jupyter_ui as jcv2
from matplotlib import pyplot as plt

# %%
image = cv2.imread('Cenicienta 20.png')

# %%
jcv2.imshow("Cenicienta 20",image)

# %% [markdown]
# La caracteróstica principal del video es el TIEMPO. Cambia el color cambia x,y.Cambia la profundidad. En video podemos calcular el vector de velocidad. Si va a mucha velocidad no puede ver la direccion y no puedo ejercer el factor previsión de tiempo porque no tengo dos posiciones para sacar esto.
#
# Las operaciones que hay que hacer siempre es gris, filtral binarizar, cerrar abrir, restar imagenes. Estas operaciones se ahcen siempre. Si no hago esas operaciones tiengo que que hacer la opercion a bajo nivel CPU/GPU.
#
# Elegir un video par ala práctica de 4 megas, 8 segs mas o menos, utilizar video candy
#
# Lo que vamos a hacer es coger un objeto y seguirlo, ver donde esta pasado algún tiempo (barcos, trenes, coches) Personas anddno, gente entradn y salienod de una tienda, rebaño de ovejas. Autovia (densidad de trafico) Importante que no se mueva la camara (tipo camara de seguridad). Recomendación que lo hagamos en anaconda para tener videos más grandes.

# %% [markdown]
# El lenguaje de sripting (python), se ejecuta junto al usuario,
# Lo que describe python, para que se 'leea y jecute' el código hay un interpreatdor de pythn, que hace que te haga las fuciones a bajo nivel. Ej: print('hola') coje eso y lo pasa al sistema operativo para que canalice a la CPU y a la memoria para que a la pantalla le llegue la orden de imprimir hola.

# %%
cars = cv2.imread('cars.jng')

# %% [markdown]
# el procesamiendo se hacia eb show the image
#
# Para procesar a muy bajo nivel:
#
#
# backeraser = cv2.createBackgroundSubstractorMOG2(history=50)
# (el manado esto a la GPU, direactamte al compilador)
#
# mask = backeraser.apply(image)
# (el manado esto a la GPU, direactamte al compilador)

# %%
jcv2.imshow("cars", cars)
# Out:
# ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-a2d747d356c2> in <cell line: 1>()
# ----> 1 jcv2.imshow("cars", cars)
#
# /usr/local/lib/python3.10/dist-packages/opencv_jupyter_ui/cv2_imshow.py in cv2_imshow(name, image, width, height, colorspace, force_clear)
#      54         if height:layout['height']=f'{height}px' if type(height) ==int else height
#      55         if not (width or height):
# ---> 56                 layout['width']=f'{image.shape[1]}px'
#      57         try:
#      58
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
Importación de la biblioteca OpenCV import cv2
# Leer la imagen usando la función imread)
image = cv2. imread ("highway. jpg")
jov2. imshow("Mario" , image)
# Extraer la altura y la anchura de una imagen
h, w = image. shapel:2]
# Mostrar la altura y la anchura
print("Altura = (), Anchura = ()", formatih,
#tambien funciona
print(image .shape)
backeraser=cv2.createBackgroundSubtractor'062(history=S/ mask=backeraser .apply(image);
