# %% [markdown]
# <a href="https://colab.research.google.com/github/patriciamediavilla/L1P2/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Visualización de datos
# ## Volúmenes de venta US con predicciones
#
# #### Patricia Mediavilla

# %% [markdown]
# ## Objetivo
# Responder a las siguientes cuestiones utilizando en cada caso el diagrama más conveniente:
#
# ¿Cuáles son las 5 combinaciones de canal-producto con más volumen de cada customer?
#
# ¿Cuál es el error cuadrático medio de cada modelo de las series de la pregunta anterior?
#
# ¿Cuáles son las previsiones de los 2 mejores modelos de cada customer de las series de la pregunta anterior?
#
# ## Desarrollo
# ### Importación de librerías

# %%
pip install plotly_express

# %%
import plotly_express as px
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Lectura y limpieza de la base de datos

# %%
df = pd.read_csv('volume_us_forecast_sample.csv', sep=',')
df
# Out:
# <ipython-input-20-74552a55b750>:1: DtypeWarning: Columns (11,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('volume_us_forecast_sample.csv', sep=',')
#                COUNTRY GEOGRAPHY    CUSTOMER SEGMENT/CHANNEL PRODUCT    YEAR  \
# 0        United States      West   AO_FTN_US         CG3_Z59   L2488  2023.0
# 1        United States      West   AO_FTN_US         CG3_Z59   L2488  2023.0
# 2        United States      West   AO_FTN_US         CG3_Z59   L2488  2023.0
# 3        United States      West   AO_FTN_US         CG3_Z59   L2488  2023.0
# 4        United States      West   AO_FTN_US         CG3_Z59   L2488  2023.0
# ...                ...       ...         ...             ...     ...     ...
# 1125282  United States     North   AO_FTN_US         CG3_Z59   L2487  2021.0
# 1125283  United States   Central  1000006156         CG2_Z01   L2248  2021.0
# 1125284  United States   Central  1000006156         CG2_Z16   L2304  2021.0
# ...

# %% [markdown]
# Esta es nuestra base de datos, vamos a hacer un reconocimiento de los datos:
# - COUNTRY
# - GEOGRAPHY
# - CUSTOMER
# - SEGMENT/CHANNEL
# - PRODUCT
# - YEAR
# - WEEK
# - SCENARIO
# - SCENARIO_LVL_2
# - AMOUNT
# - MODEL_ID
# - MODEL_CAT
# - DEFAULT_MODEL
# - FORECAST_YEAR
# - FORECAST
# - UNIT
# - AMOUNT_WITHOUT_OUTLIERS
#
# Vamos a hacer un epqueño procesamiento de los datos.

# %%
valores_faltantes = df.isnull().sum()
print(valores_faltantes)
# Out:
# COUNTRY                          0
# GEOGRAPHY                        1
# CUSTOMER                         1
# SEGMENT/CHANNEL                  1
# PRODUCT                          1
# YEAR                             1
# WEEK                             1
# SCENARIO                         1
# SCENARIO_LVL_2                   1
# AMOUNT                           1
# MODEL_ID                    267393
# MODEL_CAT                   267393
# DEFAULT_MODEL                    1
# FORECAST_YEAR               267393
# FORECAST                    267393
# UNIT                             1
# AMOUNT_WITHOUT_OUTLIERS    1125287
# dtype: int64

# %%
df.describe()
# Out:
#                YEAR          WEEK        AMOUNT       MODEL_ID  DEFAULT_MODEL  \
# count  1.125286e+06  1.125286e+06  1.125286e+06  857894.000000   1.125286e+06
# mean   2.022741e+03  1.990071e+01  7.970800e+03       0.582551   6.817458e-01
# std    6.040085e-01  1.011505e+01  4.447483e+04       0.493139   4.657989e-01
# min    2.021000e+03  1.000000e+00 -1.402394e+05       0.000000   0.000000e+00
# 25%    2.023000e+03  1.300000e+01  0.000000e+00       0.000000   0.000000e+00
# 50%    2.023000e+03  1.900000e+01  1.279700e+01       1.000000   1.000000e+00
# 75%    2.023000e+03  2.600000e+01  6.486383e+02       1.000000   1.000000e+00
# max    2.023000e+03  5.300000e+01  1.552496e+06       1.000000   1.000000e+00
#
#        FORECAST_YEAR  AMOUNT_WITHOUT_OUTLIERS
# count       857894.0                      0.0
# mean          2023.0                      NaN
# std              0.0                      NaN
# min           2023.0                      NaN
# ...

# %%
df['AMOUNT'] = df['AMOUNT'][df['AMOUNT'] >= 0]

resumen = df['AMOUNT'].describe()
resumen
# Out:
# count    9.690850e+05
# mean     9.354114e+03
# std      4.772569e+04
# min      0.000000e+00
# 25%      2.951272e-01
# 50%      4.632853e+01
# 75%      1.152964e+03
# max      1.552496e+06
# Name: AMOUNT, dtype: float64

# %%
# Lista de columnas que deseas analizar
columnas = ['COUNTRY','GEOGRAPHY','CUSTOMER','SEGMENT/CHANNEL','PRODUCT','SCENARIO','SCENARIO_LVL_2','MODEL_CAT','FORECAST','UNIT']

# Itera a través de las columnas y muestra el conteo de valores únicos
for columna in columnas:
    conteo_valores = df[columna].value_counts()
    print(f'Conteo de valores en la columna "{columna}":')
    print(conteo_valores)
    print('\n')
# Out:
# Conteo de valores en la columna "COUNTRY":
# United States    1125286
# United Stat            1
# Name: COUNTRY, dtype: int64
#
#
# Conteo de valores en la columna "GEOGRAPHY":
# South      362212
# Central    279378
# North      250449
# West       233247
# Name: GEOGRAPHY, dtype: int64
#
#
# Conteo de valores en la columna "CUSTOMER":
# 1000006156    464809
# AO_FTN_US     225152
# 1000007206    208564
# 1000008742    140403
# 1000007013     86358
# Name: CUSTOMER, dtype: int64
#
#
# Conteo de valores en la columna "SEGMENT/CHANNEL":
# CG2_Z01          282270
# CG2_Z19          196496
# CG2_Z16          172701
# CG2_Z30           79453
# CG2_Z08           56319
# CG2_Z27           51459
# CG3_Z59           28250
# CG2_Z10           19207
# CG2_Z17           15867
# 2FS               12938
# CG3_Z34           12881
# CG3_Z55           12773
# CG3_Z81           12689
# ZZ_FSV_FTN_US     12626
# CG3_Z36           12525
# 1FS               12524
# CG3_Z49           12458
# ...

# %% [markdown]
# ## 1. ¿Cuáles son las 5 combinaciones de canal-producto con más volumen de cada cliente?

# %%
#Seleccionamos de los actuals
df1 = df[df["SCENARIO"]=='actual']

# Agrupa por cliente, canal y producto, y suma el volumen
comb = df1.groupby(['CUSTOMER', 'SEGMENT/CHANNEL', 'PRODUCT'])['AMOUNT'].sum().reset_index()

# Ordena en orden descendente y obtén las 5 combinaciones principales por cliente
top_combinaciones = comb.groupby('CUSTOMER').apply(lambda x: x.nlargest(5, 'AMOUNT')).reset_index(drop=True)

df_actual = top_combinaciones
df_actual
# Out:
#       CUSTOMER SEGMENT/CHANNEL PRODUCT        AMOUNT
# 0   1000006156         CG2_Z19   L2296  1.854797e+08
# 1   1000006156         CG2_Z19   L2254  1.610450e+08
# 2   1000006156         CG2_Z19   L2306  8.279452e+07
# 3   1000006156         CG2_Z19   L2291  6.603755e+07
# 4   1000006156         CG2_Z19   L2315  4.888147e+07
# 5   1000007013         CG2_Z30   L2254  1.595294e+08
# 6   1000007013         CG2_Z30   L2300  1.189205e+08
# 7   1000007013         CG2_Z30   L2381  3.204837e+07
# 8   1000007013         CG2_Z30   L2313  1.378402e+07
# 9   1000007013         CG2_Z30   L2264  1.234998e+07
# 10  1000007206         CG2_Z01   L2350  2.837171e+07
# 11  1000007206         CG2_Z01   L2311  1.739289e+07
# 12  1000007206         CG2_Z01   L2266  9.633411e+06
# 13  1000007206         CG2_Z01   L2253  7.848946e+06
# 14  1000007206         CG2_Z01   L2315  7.320655e+06
# 15  1000008742         CG2_Z08   L2306  1.931587e+07
# 16  1000008742         CG2_Z08   L2253  1.772205e+07
# ...

# %%
# Crear un gráfico de barras para cada cliente
colores = ['#87CEEB'] * 5

for customer, customer_data in df_actual.groupby('CUSTOMER'):
    plt.figure(figsize=(10, 6))
    plt.barh(customer_data['SEGMENT/CHANNEL'] + ' - ' + customer_data['PRODUCT'], customer_data['AMOUNT'], color=colores)
    plt.title(f'Combinaciones de canal-producto con más volumen para {customer}')
    plt.xlabel('Combinación de Canal-Producto')
    plt.ylabel('Volumen')
    plt.xticks(rotation=45, ha='right')
    plt.show()

# %% [markdown]
# ## 2. ¿Cuál es el error cuadrático medio de cada modelo de las series de la pregunta anterior?

# %%
df2 = df[df["SCENARIO"]=='AI_forecast']

# %%
# Primero debemos obtener los customers/canales/productos obtenidos anteriormente en el primer apartado separados por fechas
# es decir, como si fuera una serie temporal.
# Esto lo realizamos para los actuals, y para los forecast debemos tener en cuenta además cuando se realizó dicho forecast y con que modelo.
df1_week = df1.groupby(['YEAR', 'WEEK', 'CUSTOMER', 'SEGMENT/CHANNEL', 'PRODUCT'])['AMOUNT'].mean().reset_index()
df2_week = df2.groupby(['YEAR', 'WEEK', 'CUSTOMER', 'SEGMENT/CHANNEL', 'PRODUCT', 'MODEL_ID'])['AMOUNT'].mean().reset_index()

df_week = df1_week.join(df2_week.set_index(['YEAR', 'WEEK', 'CUSTOMER','SEGMENT/CHANNEL', 'PRODUCT']),
                                           on = ['YEAR', 'WEEK', 'CUSTOMER','SEGMENT/CHANNEL', 'PRODUCT'], how = 'inner', lsuffix='_actual', rsuffix='_ai_forecast')

#pasamos la fecha a formato fecha y la ponemos en una columa
df_week['DATE'] = pd.to_datetime(df_week['YEAR'].astype(int).astype(str) + '-' + df_week['WEEK'].astype(int).astype(str) + '-' + '1', format='%Y-%W-%w')

#Error cuadrático medio cada semana
df_week['MSE'] = (df_week['AMOUNT_actual'] - df_week['AMOUNT_ai_forecast'])**2

import pandas as pd
import plotly.express as px

# Supongamos que ya tienes df_week con las columnas necesarias, incluyendo 'AMOUNT_MSE'

# Lista única de clientes
clientes_unicos = df_week['CUSTOMER'].unique()

for cliente in clientes_unicos:
    customer_data = df_week[df_week['CUSTOMER'] == cliente]

    for i in range(len(df_actual)):
        segment_channel = df_actual.iloc[i]['SEGMENT/CHANNEL']
        product = df_actual.iloc[i]['PRODUCT']

        # Filtra el DataFrame por cliente, canal/producto y modelo
        filtro = (df_week['CUSTOMER'] == cliente) & (df_week['SEGMENT/CHANNEL'] == segment_channel) & (df_week['PRODUCT'] == product)
        channel_product_data = df_week[filtro]

        # Grafica la serie temporal de MSE
        fig = px.line(channel_product_data, x='DATE', y='MSE', color='MODEL_ID', markers=True,
                  title=f'CUSTOMER: {cliente}; CHANNEL: {segment_channel}; PRODUCT: {product}')

        fig.show()

    # Agrupa y grafica el MSE total por canal/producto y modelo
    df_vacio = channel_product_data.groupby(['CUSTOMER', 'SEGMENT/CHANNEL', 'PRODUCT', 'MODEL_ID'])['MSE'].mean().reset_index()

    fig_total_mse = px.histogram(df_vacio, x='SEGMENT/CHANNEL', y='MSE', color='MODEL_ID',
                                  title=f'CUSTOMER: {cliente}', barmode='group', text_auto='.2s')
    fig_total_mse.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Primero debemos obtener los customers/canales/productos obtenidos anteriormente en el primer apartado separados por fechas
# es decir, como si fuera una serie temporal.
# Esto lo realizamos para los actuals, y para los forecast debemos tener en cuenta además cuando se realizó dicho forecast y con que modelo.
df1_week = df1.groupby(['YEAR', 'WEEK', 'CUSTOMER', 'SEGMENT/CHANNEL', 'PRODUCT'])['AMOUNT'].mean().reset_index()
df2_week = df2.groupby(['YEAR', 'WEEK', 'CUSTOMER', 'SEGMENT/CHANNEL', 'PRODUCT', 'MODEL_ID'])['AMOUNT'].mean().reset_index()

df_week = df1_week.join(df2_week.set_index(['YEAR', 'WEEK', 'CUSTOMER','SEGMENT/CHANNEL', 'PRODUCT']),
                                           on = ['YEAR', 'WEEK', 'CUSTOMER','SEGMENT/CHANNEL', 'PRODUCT'], how = 'inner', lsuffix='_actual', rsuffix='_ai_forecast')

#pasamos la fecha a formato fecha y la ponemos en una columa
df_week['DATE'] = pd.to_datetime(df_week['YEAR'].astype(int).astype(str) + '-' + df_week['WEEK'].astype(int).astype(str) + '-' + '1', format='%Y-%W-%w')

#Error cuadrático medio cada semana
df_week['MSE'] = (df_week['AMOUNT_actual'] - df_week['AMOUNT_ai_forecast'])**2

for customers in customer:
  channel_product = customer_data[customer_data['CUSTOMER'] == customers]
  channel_product = channel_product.sort_values(by = 'AMOUNT', ascending = False)[0:5]

  df_vacio = pd.DataFrame()
  # Número de filas
  numFilas = channel_product.shape[0]

  for i in range(0, numFilas):
    fila = channel_product.iloc[i]

    # Establecemos que solo queremos aquellos datos que cumplan esta condición
    condicion = (df_week['CUSTOMER'] == customers) & (df_week['SEGMENT/CHANNEL'] == fila['SEGMENT/CHANNEL']) & (df_week['PRODUCT'] == fila['PRODUCT'])

    # Dividimos nuestros valores entro lo que "n", número de filas que cumplen dicha condición
    df_week[condicion]['AMOUNT_MSE'] = df_week[condicion]['AMOUNT_MSE']

    # Lo guardamos en el dataframe, de tal forma que al final de este bucle, esta variable contendra
    # el error cuadrático medio por fecha de cada customer/canal/producto
    df_vacio = pd.concat([df_vacio, df_week[condicion]], ignore_index = True)

    # Graficamos la serie temporal de los MSE en un gráfico de líneas
    px.line(df_week[condicion], x = 'DATE', y = 'AMOUNT_MSE', color = 'MODEL_ID', markers=True,
            title = 'CUSTOMER: ' + customers + '; CHANNEL: ' + fila['SEGMENT/CHANNEL'] + '; PRODUCT: ' + fila['PRODUCT']).show()

  df_vacio['channel-product'] = df_vacio['SEGMENT/CHANNEL'] + '-' + df_vacio['PRODUCT']
  df_vacio = df_vacio.groupby(['CUSTOMER', 'channel-product', 'MODEL_ID'])['AMOUNT_MSE'].mean().reset_index()

  # Por último, graficamos el MSE total por cada uno de ellos para saber cuales de ellos son los que tiene
  # menor MSE
  px.histogram(df_vacio, x = 'channel-product', y = 'AMOUNT_MSE',
               color = 'MODEL_ID', title = 'CUSTOMER: ' + customers, barmode = 'group',
               text_auto='.2s').show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SEGMENT/CHANNEL'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df_vacio
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Define los valores específicos que deseas filtrar
cliente = "1000006156"
canal = "CG2_Z19"
producto = "L2296"

# Filtra los datos en función de los valores específicos
nueva_bbdd = df[(df['CUSTOMER'] == cliente) & (df['SEGMENT/CHANNEL'] == canal) & (df['PRODUCT'] == producto)]
nueva_bbdd['MODEL_ID'] = nueva_bbdd['MODEL_ID'].fillna(2).astype(int)
nueva_bbdd_actual = nueva_bbdd[nueva_bbdd["MODEL_ID"] == 2]
nueva_bbdd_ai_forcast0 = nueva_bbdd[nueva_bbdd["MODEL_ID"] == 0]
nueva_bbdd_ai_forcast1 = nueva_bbdd[nueva_bbdd["MODEL_ID"] == 1]
# Out:
# <ipython-input-82-ff736018e09b>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nueva_bbdd['MODEL_ID'] = nueva_bbdd['MODEL_ID'].fillna(2).astype(int)

# %% [markdown]
# # Filtra los datos "AI_forecast" para las mismas combinaciones de canales y productos de "actuals"
# df2 = df[(df["SCENARIO"] == 'AI_forecast') &
#           df.set_index(['CUSTOMER', 'SEGMENT/CHANNEL', 'PRODUCT']).index.isin(df_actual.set_index(['CUSTOMER', 'SEGMENT/CHANNEL', 'PRODUCT']).index)
#           ][['CUSTOMER', 'SEGMENT/CHANNEL', 'PRODUCT', 'AMOUNT']]
#
# # Agrupa por cliente, canal y producto, y suma el volumen
# df_ai_forecast = df2.groupby(['CUSTOMER', 'SEGMENT/CHANNEL', 'PRODUCT']).sum().reset_index()
#
# df_ai_forecast

# %%
# Filtra los datos "AI_forecast" para las mismas combinaciones de canales y productos de "actuals"
df2 = df[(df["SCENARIO"] == 'AI_forecast') &
          df.set_index(['CUSTOMER', 'SEGMENT/CHANNEL', 'PRODUCT']).index.isin(df_actual.set_index(['CUSTOMER', 'SEGMENT/CHANNEL', 'PRODUCT']).index)
          ][['CUSTOMER', 'SEGMENT/CHANNEL', 'PRODUCT', 'AMOUNT']]

# Agrupa por cliente, canal y producto, y suma el volumen
df_ai_forecast = df2.groupby(['CUSTOMER', 'SEGMENT/CHANNEL', 'PRODUCT']).sum().reset_index()

# %%
df2
# Out:
#               COUNTRY GEOGRAPHY    CUSTOMER SEGMENT/CHANNEL PRODUCT    YEAR  \
# 0       United States      West   AO_FTN_US         CG3_Z59   L2488  2023.0
# 1       United States      West   AO_FTN_US         CG3_Z59   L2488  2023.0
# 2       United States      West   AO_FTN_US         CG3_Z59   L2488  2023.0
# 3       United States      West   AO_FTN_US         CG3_Z59   L2488  2023.0
# 4       United States      West   AO_FTN_US         CG3_Z59   L2488  2023.0
# ...               ...       ...         ...             ...     ...     ...
# 253025  United States   Central  1000006156         CG2_Z19   L2498  2023.0
# 253026  United States   Central  1000006156         CG2_Z19   L2498  2023.0
# 253027  United States   Central  1000006156         CG2_Z19   L2498  2023.0
# 253028  United States   Central  1000006156         CG2_Z19   L2498  2023.0
# 253029  United States   Central  1000006156         CG2_Z19   L2498  2023.0
#
# ...

# %%
# Convierte 'YEAR' y 'WEEK' a tipo entero para formatearlos
# df['YEAR'] = df['YEAR'].astype(int)
# df['WEEK'] = df['WEEK'].astype(int)

# # Convierte 'YEAR' y 'WEEK' a tipo str (cadena) para formatearlos
df['YEAR'] = df['YEAR'].astype(str)
df['WEEK'] = df['WEEK'].astype(str)

# Combina 'YEAR' y 'WEEK' en una nueva columna 'FECHA' con el formato 'año-semana'
df['FECHA'] = pd.to_datetime(df['YEAR'] + '-' + df['WEEK']+'-' + '1', format = "%Y-%W-%w")
df_actual['FECHA'] =pd.to_datetime(df['YEAR'] + '-' + df['WEEK']+'-' + '1', format = "%Y-%W-%w")
df_ai_forecast['FECHA'] = pd.to_datetime(df['YEAR'] + '-' + df['WEEK']+'-' + '1', format = "%Y-%W-%w")

df_ai_forecast2 = df[df["SCENARIO"]=='AI_forecast']
df_actual2 = df[df["SCENARIO"]=='actual']

# %%
# Agrupa por cliente, canal, producto y fecha, y suma el volumen
df_ai_forecast_fecha2 = df_ai_forecast.groupby(['CUSTOMER', 'SEGMENT/CHANNEL', 'PRODUCT', 'FECHA']).sum().reset_index()
# Agrupa por cliente, canal, producto y fecha, y suma el volumen
df_actual_fecha2 = df_actual.groupby(['CUSTOMER', 'SEGMENT/CHANNEL', 'PRODUCT', 'FECHA']).sum().reset_index()

# %% [markdown]
# # Filtra los datos "AI_forecast" para las mismas combinaciones de canales y productos de "actuals"
# df_actual2 = df[df.set_index(['CUSTOMER', 'SEGMENT/CHANNEL', 'PRODUCT','FECHA']).index.isin(df_actual.set_index(['CUSTOMER', 'SEGMENT/CHANNEL', 'PRODUCT', 'FECHA']).index)
#           ][['CUSTOMER', 'SEGMENT/CHANNEL', 'PRODUCT', 'FECHA', 'AMOUNT']]
#
# # Agrupa por cliente, canal, producto y fecha, y suma el volumen
# df_actual_fecha2 = df_actual2.groupby(['CUSTOMER', 'SEGMENT/CHANNEL', 'PRODUCT', 'FECHA']).sum().reset_index()

# %% [markdown]
# ## Creo que esto esta bien

# %%
mse_final = []

for i in range(df_ai_forecast_fecha2.shape[0]):

    actual_amount = df_actual_fecha2['AMOUNT'].iloc[i]  # Obtener el valor 'AMOUNT' en la fila i
    forecast_amount = df_ai_forecast_fecha2['AMOUNT'].iloc[i]  # Obtener el valor 'AMOUNT' en la fila i

    # Calcular el MSE entre los valores actual y forecast
    mse = ((actual_amount - forecast_amount) ** 2).mean()
    mse_final.append({'MSE': mse})

# Crea un DataFrame con los resultados
mse_df = pd.DataFrame(mse_final)

#Contatena con producto, canla y customer.
resultado_df = mse_df.merge(df_ai_forecast_fecha2[['CUSTOMER', 'SEGMENT/CHANNEL', 'PRODUCT']], left_index=True, right_index=True, how='inner')

resultado_df
# Out:
#              MSE    CUSTOMER SEGMENT/CHANNEL PRODUCT
# 0   6.588925e+17  1000006156         CG2_Z19   L2254
# 1   1.032113e+17  1000006156         CG2_Z19   L2291
# 2   4.568760e+17  1000006156         CG2_Z19   L2296
# 3   9.375633e+16  1000006156         CG2_Z19   L2306
# 4   2.837244e+16  1000006156         CG2_Z19   L2315
# 5   4.580159e+17  1000007013         CG2_Z30   L2254
# 6   4.083548e+15  1000007013         CG2_Z30   L2264
# 7   2.534309e+17  1000007013         CG2_Z30   L2300
# 8   3.186873e+15  1000007013         CG2_Z30   L2313
# 9   1.282018e+16  1000007013         CG2_Z30   L2381
# 10  1.871163e+15  1000007206         CG2_Z01   L2253
# 11  1.286710e+15  1000007206         CG2_Z01   L2266
# 12  5.807279e+15  1000007206         CG2_Z01   L2311
# 13  6.415382e+14  1000007206         CG2_Z01   L2315
# 14  1.510228e+16  1000007206         CG2_Z01   L2350
# 15  6.162885e+15  1000008742         CG2_Z08   L2253
# 16  3.016911e+15  1000008742         CG2_Z08   L2291
# ...

# %%
mse_final = []

for customer in df_actual['CUSTOMER'].unique():
    actual = df_actual[df_actual['CUSTOMER'] == customer]
    ai_forecast = df_ai_forecast[df_ai_forecast['CUSTOMER'] == customer]

    mse = ((ai_forecast['AMOUNT'] - actual['AMOUNT']) ** 2).mean()

    mse_final.append({'CUSTOMER': customer, 'MSE': mse})

# Crea un DataFrame con los resultados
mse_df = pd.DataFrame(mse_final)

# Imprime el resultado
print(mse_df)
# Out:
#      CUSTOMER           MSE
# 0  1000006156  2.903750e+17
# 1  1000007013  1.742783e+17
# 2  1000007206  6.346426e+15
# 3  1000008742  4.368537e+15
# 4   AO_FTN_US  2.384277e+17

# %%
# Ordena los resultados por MSE en orden ascendente (opcional)
mse_df = mse_df.sort_values(by='MSE', ascending=True)

# Grafica los resultados en un gráfico de barras
plt.figure(figsize=(12, 6))
plt.barh(mse_df['CUSTOMER'], mse_df['MSE'])
plt.xlabel('MSE (Error Cuadrático Medio)')
plt.ylabel('Cliente')
plt.title('MSE por Cliente')
plt.grid(axis='x', linestyle='--', alpha=0.6)
plt.tight_layout()

# Muestra el gráfico
plt.show()

# %%
# Agrupa los datos de ventas reales por semana.
ventas_semana_real = df_actual.groupby([pd.Grouper(key='FECHA', freq='W')])['AMOUNT'].sum()

# Agrupa los datos de predicciones por semana y modelo 0
df_ai_forecast['MODEL_ID'] = df['MODEL_ID'].astype(int)
df_ai_forecast_modelo0 = df_ai_forecast[df_ai_forecast['MODEL_ID'==0]]
ventas_semana_predicciones_modelo0 = df_ai_forecast_modelo0.groupby([pd.Grouper(key='FECHA', freq='W')])['AMOUNT'].sum()

# Agrupa los datos de predicciones por semana.
ventas_semana_predicciones_modelo1 = df_ai_forecast_modelo1.groupby([pd.Grouper(key='FECHA', freq='W')])['AMOUNT'].sum()

# Crea un gráfico de líneas que muestre tanto las ventas reales como las predicciones en la misma gráfica.
plt.figure(figsize=(12, 6))
plt.plot(ventas_semana_real.index, ventas_semana_real, label='Ventas Reales', color='blue')
plt.plot(ventas_semana_predicciones.index, ventas_semana_predicciones, label='Predicciones', color='red')
plt.title('Serie Temporal de Volumen de Ventas por Semana')
plt.xlabel('Semana')
plt.ylabel('Volumen de Ventas')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# <ipython-input-73-def41754ef07> in <cell line: 5>()
#       3
#       4 # Agrupa los datos de predicciones por semana y modelo 0
# ----> 5 df_ai_forecast['MODEL_ID'] = df['MODEL_ID'].astype(int)
#       6 df_ai_forecast_modelo0 = df_ai_forecast[df_ai_forecast['MODEL_ID'==0]]
#       7 ventas_semana_predicciones_modelo0 = df_ai_forecast_modelo0.groupby([pd.Grouper(key='FECHA', freq='W')])['AMOUNT'].sum()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6238         else:
#    6239             # else, only a single dtype is given
# -> 6240             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241             return self._constructor(new_data).__finalize__(self, method="astype")
#    6242
#
# ...

# %% [markdown]
# ## 3. ¿Cuáles son las previsiones de los 2 mejores modelos de cada customer de las series de la pregunta anterior?
